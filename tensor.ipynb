# %%
# !pipenv install pandas
# Out:
# ^C

# %%
import pandas as pd

pd.__version__

data ={'Maths': [90, 55, 73], 'English': [92,85, 58], 'Biology': [93, 46, 69]}
pd.DataFrame(data)
# Out:
#    Maths  English  Biology
# 0     90       92       93
# 1     55       85       46
# 2     73       58       69
